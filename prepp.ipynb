# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
from os.path import join

# %%
GIT_token = "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"
GIT_username = "hyeminyoo11"
GIT_repo = "PortfolioProjects"
GIT_path = "https://" + GIT_token + "@github.com/" + GIT_username + "/" + GIT_repo + ".git"
print(GIT_path)

# %%
PROJ_path = "/content/drive/MyDrive/Colab Notebooks/"
# %cd "{PROJ_path}"
# %pwd

# %%
# !git config --global user.name "hyeminyoo"
# !git config --global user.email "hyeminyoo11@gmail.com"
# !git config --global user.password "commIT0226!"

# %%
# !git status

# %%
# !git clone http://{GIT_token}@github.com/{GIT_username}/{GIT_repo}

# %%
# %cd {GIT_repo}

# %%
# %ls

# %%
# !mv /content/Chapter2_housing.csv /content/drive/MyDrive/Colab_Notebooks/PortfolioProjects

# %%
# !git status

# %%
# !git add --all

# %%
# !git commit -a -m "add a file"

# %%
# !git remote -v

# %%
# !git push origin master
